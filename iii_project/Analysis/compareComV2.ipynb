# %% [markdown]
# ## Cleaning the raw data from the 104 website

# %%
def clean_compInfo(url):
    company=[]
    f = open(url,'r')  
    for comps in f.readlines():
        tempdata = comps.split(',')[0].split('股份有限公司')[0].split('有限公司')[0]
        company.append(tempdata)
    company = list(set(company))  # eliminating duplicat
    f.close()
    return company

# %%
url='/Users/yvette/GoogleDrive/ZB105_no_5_project/companyFiles/compare_companyName/'
complist=[]
filepath = url+'104comm0329.txt'
company=clean_compInfo(filepath)
complist.append(company)
print len(complist)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-62-9458b115d3ed> in <module>()
#       2 complist=[]
#       3 filepath = url+'104comm0329.txt'
# ----> 4 company=clean_compInfo(filepath)
#       5 complist.append(company)
#       6 print len(complist)
#
# <ipython-input-61-a1e36c0417b3> in clean_compInfo(url)
#       3     f = open(url,'r')
#       4     for comps in unicode(f.readlines()):
# ----> 5         tempdata = comps.split(',')[0].split('股份有限公司')[0].split('有限公司')[0]
#       6         company.append(tempdata)
#       7     company = list(set(company))  # eliminating duplicat
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe8 in position 0: ordinal not in range(128)

# %%
print type(complist)
# Out:
# <type 'list'>

# %%
for ele in complist:
    print unicode(ele)
# Out:
# ['\xe9\x9c\x96\xe5\x85\x89\xe4\xbc\x81\xe6\xa5\xad\xe7\xa4\xbe', '\xe8\x81\xaf\xe6\x88\x90\xe5\x9c\x8b\xe9\x9a\x9b', '\xe8\xa1\x8c\xe5\xae\xb6\xe9\x80\x9a\xe4\xbf\xa1\xe4\xbc\x81\xe6\xa5\xad', '\xe4\xb8\x96\xe5\x90\x8c\xe9\x9b\xbb\xe5\xad\x90', '\xe8\x97\x9d\xe7\x8f\x82\xe4\xba\xba\xe4\xba\x8b\xe9\xa1\xa7\xe5\x95\x8f', '\xe6\x98\x87\xe9\xa0\xbb', '\xe5\xba\xb7\xe6\xb3\x95\xe7\xa7\x91\xe6\x8a\x80', '\xe6\xa0\xbc\xe5\xbe\x97\xe9\x9b\xbb\xe5\xad\x90\xe5\xb7\xa5\xe6\xa5\xad', '\xe7\x8e\xa9\xe6\xa8\x82\xe6\x95\xb4\xe5\x90\x88\xe8\xa1\x8c\xe9\x8a\xb7', '\xe4\xb8\x8a\xe6\x96\xb0\xe4\xba\xba\xe4\xba\x8b\xe7\xae\xa1\xe7\x90\x86\xe9\xa1\xa7\xe5\x95\x8f', '\xe7\xab\x8b\xe5\x81\x89\xe9\x80\x9a\xe4\xbf\xa1', '\xe9\x81\xa0\xe5\x82\xb3\xe9\x9b\xbb\xe4\xbf\xa1', '\xe6\xb0\xb8\xe9\xa8\xb0\xe5\xb7\xa5\xe7\xa8\x8b\xe8\xa1\x8c', '\xe5\x84\xaa\xe6\x87\x8b\xe7\xb6\xb2\xe9\x9b\xbb\xe7\xa7\x91\xe6\x8a\x80', '\xe5\xa4\xa7\xe9\x83\xbd\xe6\x9c\x83\xe8\xa1\x9b\xe6\x98\x9f\xe8\xbb\x8a\xe9\x9a\x8a', '\xe9\x81\xa0\xe5\x82\xb3\xe9\x9b\xbb\xe4\xbf\xa1\xe6\xb0\xb8\xe5\xba\xb7\xe5\xa4\xa7\xe7\x81\xa3\xe7\x89\xb9\xe7\xb4\x84\xe6\
\xa9\xe6\x91\xa9\xe4\xba\x9e\xe5\x95\x86\xe6\x96\xb0\xe8\x8c\x82\xe7\x92\xb0\xe7\x90\x83', '\xe8\x8f\xaf\xe6\x99\xba\xe9\x80\x9a\xe4\xbf\xa1', '\xe8\x81\xaf\xe8\xb1\xaa\xe9\x9b\xbb\xe8\xa8\x8a', '\xe9\x9b\xb2\xe5\xb1\xb1\xe9\xb3\xb4\xe4\xbc\x81\xe6\xa5\xad', '\xe4\xb9\x9f\xe7\xbf\x94\xe5\x9c\x8b\xe9\x9a\x9b', '\xe9\x9b\xb2\xe5\x89\xb5\xe9\x80\x9a\xe8\xa8\x8a', '\xe6\x98\x93\xe9\x80\x9a\xe5\xb1\x95\xe7\xa7\x91\xe6\x8a\x80', '\xe4\xb8\xbb\xe5\x90\x91\xe4\xbd\x8d\xe7\xa7\x91\xe6\x8a\x80', '\xe5\xb0\xbc\xe9\x87\x87\xe5\xaf\xa6\xe6\xa5\xad', 'TomTom Asia_\xe9\x80\x9a\xe9\xa8\xb0\xe7\xa7\x91\xe6\x8a\x80', '\xe8\xb3\x88\xe4\xbc\xaf\xe6\x96\xaf3C_\xe8\xb3\x88\xe4\xbc\xaf\xe6\x96\xaf\xe9\x80\x9a\xe4\xbf\xa1\xe7\xa4\xbe', '\xe7\xa5\x9e\xe6\xba\x96\xe7\xa7\x91\xe6\x8a\x80', '\xe4\xba\xba\xe5\x88\xa9', '104\xe5\xa4\x96\xe5\x8c\x85\xe7\xb6\xb2', '\xe7\x80\x9a\xe9\x8a\x98\xe7\xa7\x91\xe6\x8a\x80', '\xe5\x82\xb3\xe4\xb8\x96\xe5\xb7\xa5\xe7\xa8\x8b', '\xe5\x8f\xb0\xe7\x81\xa3\xe5\xa4\xa7\xe5\x93\xa5\xe5\xa4\xa7\xe7\x89\xb9\xe7\xb4\x84\xe6\x9c\x8d\xe5\x8b\x99\xe9\x96\x80\xe5\xb8\x82_\xe6\xb3\x9b\xe9\x83\xbd\xe9\x9b\xbb\xe8\xa8\x8a', '\xe5\xae\x87\xe6\x81\x92\xe9 ...

# %%
url='/Users/yvette/GoogleDrive/ZB105_no_5_project/companyFiles/compare_companyName/'
complist=[]
filepath = url+'104comm0329.txt'
clean_compInfo(filepath,complist)
print len(complist)
filepath = url+'104elec0329.txt'
clean_compInfo(filepath,complist)
print len(complist)
# change to compared data
comparedData=[]
filepath = url+'company_list.txt'
clean_compInfo(filepath,comparedData)

# %%
for ele in complist[1:50]:
    print ele
# Out:
# 台灣優勢客服科技
# 台灣優勢客服科技
# 薩摩亞商新茂環球
# 薩摩亞商新茂環球
# 薩摩亞商新茂環球
# 哈拉網通電訊
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 寶華人力資源顧問
# 易通展科技
# 致振企業
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 哈拉網通電訊
# 人利
# 人利
# 人利
# 皇家電訊科技
# 皇家電訊科技
# 皇家電訊科技
# 皇家電訊科技
# 皇家電訊科技
# 皇家電訊科技

# %%
import jieba
